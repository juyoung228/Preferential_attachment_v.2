0, 32.0, 51.0, 67.5, 74.0, 208.0, 44.0, 65.0, 49.0, 44.0, 45.0, 91.0, 18.0, 18.0, 129.0, 21.0, 39.0, 56.5, 75.0, 37.0, 136.0, 23.0, 74.0, 57.0, 63.0, 45.0, 74.0, 84.0, 176.0, 84.0, 33.0, 385.0, 54.0, 84.0, 157.0, 147.0, 11.0, 85.0, 61.0, 136.0, 75.0, 164.0, 51.0, 107.0, 79.0, 50.0, 66.0, 68.0, 179.0, 38.0, 17.0, 135.0, 103.0, 51.0, 65.0, 382.0, 18.0, 61.0, 146.0, 24.0, 53.0, 66.0, 68.0, 293.0, 58.5, 51.0, 35.0, 53.0, 124.0, 95.33333333333333, 127.0, 105.0, 42.0, 1116.0, 47.0, 78.0, 140.0, 139.0, 138.0, 60.0, 72.0, 106.0, 83.0, 180.0, 127.0, 125.0, 61.0, 94.0, 52.0, 137.0, 66.0, 48.0, 51.0, 139.0, 30.0, 61.0, 472.0, 240.0, 95.0, 218.0, 184.0, 299.0, 29.0, 108.0, 544.0, 145.0, 97.0, 100.0, 145.0, 122.0, 125.0, 271.0, 132.0, 336.0, 133.0, 596.0, 215.0, 126.0, 386.0, 211.0, 130.0, 146.0]

a = np.asarray(a, dtype=float)
b = np.asarray(b, dtype=float)

logA = np.where(a>0, np.log10(a), 0)
logB = np.where(b>0, np.log10(b), 0)


coefficients = np.polyfit(logA, logB, 1)
polynomial = np.poly1d(coefficients)
ys = polynomial(a)
#plt.plot(logA, logB, 'ro')
plt.loglog(a, ys)


#coefficients=np.polyfit(b,a,1)
#polynomial=np.poly1d(coefficients)
#ys=polynomial(b)
print (polynomial)
plt.loglog(a,b,'ro')
#plt.plot(b,ys)
plt.xlabel("Log (Rank of frequency)")
plt.ylabel("Log (Frequency)")
plt.title("Frequency vs frequency rank for words")
plt.show()
# Out:
# C:\Users\Administrator\Anaconda3\lib\site-packages\ipykernel\__main__.py:9: RuntimeWarning: divide by zero encountered in log10
# C:\Users\Administrator\Anaconda3\lib\site-packages\ipykernel\__main__.py:10: RuntimeWarning: divide by zero encountered in log10
#
# 0.9678 x - 0.9486

# %%
            
a = np.asarray(a, dtype=float)
b = np.asarray(b, dtype=float)

logA = np.where(a>0, np.log10(a), 0)
logB = np.where(b>0, np.log10(b), 0)


coefficients = np.polyfit(logA, logB, 1)
polynomial = np.poly1d(coefficients)
ys = polynomial(a)
    #plt.plot(logA, logB, 'ro')
    #fit = np.polyfit(logA, logB, deg=1)
    #ax=plt.gca()
    #ax.plot(logA, fit[0] *logA + fit[1], color='blue') # add reg line

    #ax.scatter(x,y,c="blue",alpha=0.95,edgecolors='none')
    #ax.set_yscale('log')
    #ax.set_xscale('log')
   

    #coefficients=np.polyfit(b,a,1)
    #polynomial=np.poly1d(coefficients)
    #ys=polynomial(b)
    #print (polynomial)
plt.loglog(a, ys)
plt.loglog(a,b,'ro')
plt.title(polynomial)
plt.show()
# Out:
# C:\Users\Administrator\Anaconda3\lib\site-packages\ipykernel\__main__.py:6: RuntimeWarning: divide by zero encountered in log10

# %%
import glob
i = glob.glob('G:\\2017-1\\Network Science\\Project\\RESULT\\*.txt')
from scipy.stats import linregress
import numpy as np
import matplotlib.pyplot as plt

for ii in i:
    f = open(ii, 'r')
    a = []
    b = []
    for line in f:
        x1 = line.split('], [')[0]
        #print(x1)
        y1 = line.split('], [')[1]
        x2 = (x1.replace('[','').replace(']','')).split(', ')
        y2 = (y1.replace('[','').replace(']','')).split(', ')
        for x3 in x2:
            a.append(int(x3))
        for y3 in y2:
            b.append(float(y3))
            
    #print(a)
    #print(b)
    a = np.asarray(a, dtype=float)
    b = np.asarray(b, dtype=float)

    logA = np.where(a>0, np.log10(a), 0)
    logB = np.where(b>0, np.log10(b), 0)


    coefficients = np.polyfit(logA, logB, 1)
    polynomial = np.poly1d(coefficients)
    ys = polynomial(a)
    #plt.plot(logA, logB, 'ro')
    #fit = np.polyfit(logA, logB, deg=1)
    #ax=plt.gca()
    #ax.plot(logA, fit[0] *logA + fit[1], color='blue') # add reg line

    #ax.scatter(x,y,c="blue",alpha=0.95,edgecolors='none')
    #ax.set_yscale('log')
    #ax.set_xscale('log')
   

    #coefficients=np.polyfit(b,a,1)
    #polynomial=np.poly1d(coefficients)
    #ys=polynomial(b)
    #print (polynomial)
    
    print(ii+"\t"+str(polynomial[1]))
    #plt.clf()
    #plt.loglog(a, ys)
    #plt.loglog(a,b,'ro')
    #plt.title(polynomial)
    #plt.show()
    #plt.plot(logA, ys)
    #plt.plot(b,ys)
    
   

    #plt.savefig(ii+'.png')
# Out:
# G:\2017-1\Network Science\Project\RESULT\10_2010.txt	0.823117210057
# G:\2017-1\Network Science\Project\RESULT\10_2011.txt	0.824679038134
# G:\2017-1\Network Science\Project\RESULT\10_2012.txt	0.826845650164
# G:\2017-1\Network Science\Project\RESULT\10_2013.txt	0.809135908633
# G:\2017-1\Network Science\Project\RESULT\10_2014.txt	0.820839194347
# G:\2017-1\Network Science\Project\RESULT\10_2015.txt	0.826563609492
# G:\2017-1\Network Science\Project\RESULT\11_2010.txt	0.972601627825
# G:\2017-1\Network Science\Project\RESULT\11_2011.txt	0.963991921323
# G:\2017-1\Network Science\Project\RESULT\11_2012.txt	0.906670823203
# G:\2017-1\Network Science\Project\RESULT\11_2013.txt	0.880033600521
# G:\2017-1\Network Science\Project\RESULT\11_2014.txt	0.869189028266
# G:\2017-1\Network Science\Project\RESULT\11_2015.txt	0.815953076213
# G:\2017-1\Network Science\Project\RESULT\12_2010.txt	0.951144413054
# G:\2017-1\Network Science\Project\RESULT\12_2011.txt	0.957872538651
# ...
